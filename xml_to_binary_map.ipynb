# %%
import os
import xml.etree.ElementTree as ET
import numpy as np
import cv2

def convert_xml_to_mask(path_to_xml_data, path_to_bi_maps):
    # Ensure the output directory exists
    if not os.path.exists(path_to_bi_maps):
        os.makedirs(path_to_bi_maps)

    # Iterate over all XML files in the input directory
    for xml_file in os.listdir(path_to_xml_data):
        if xml_file.endswith('.xml'):
            xml_path = os.path.join(path_to_xml_data, xml_file)
            print(f"Processing: {xml_path}")

            # Parse the XML file
            try:
                tree = ET.parse(xml_path)
                root = tree.getroot()
            except ET.ParseError as e:
                print(f"Error parsing {xml_file}: {e}")
                continue

            # Get the image dimensions
            size = root.find('size')
            if size is None:
                print(f"Skipping {xml_file}: No <size> tag found.")
                continue

            try:
                width = int(size.find('width').text.strip())
                height = int(size.find('height').text.strip())
            except (AttributeError, ValueError):
                print(f"Skipping {xml_file}: Invalid width/height.")
                continue

            # Create an empty mask image
            mask = np.zeros((height, width), dtype=np.uint8)

            # Iterate over all objects in the XML file
            for obj in root.findall('object'):
                polygon = obj.find('polygon')
                if polygon is None:
                    print(f"Skipping {xml_file}: No <polygon> found in object.")
                    continue

                points = []
                i = 1  # Start with x1, y1
                while True:
                    x_tag = f"x{i}"
                    y_tag = f"y{i}"

                    x_elem = polygon.find(x_tag)
                    y_elem = polygon.find(y_tag)

                    if x_elem is None or y_elem is None:
                        break  # Stop when no more points exist

                    try:
                        x = int(float(x_elem.text.strip()))  # Convert float to int
                        y = int(float(y_elem.text.strip()))
                        points.append((x, y))
                    except (AttributeError, ValueError):
                        print(f"Skipping point in {xml_file}: Invalid x/y value.")
                        continue
                    
                    i += 1  # Move to next numbered point

                if len(points) < 3:
                    print(f"Skipping {xml_file}: Not enough points for a polygon.")
                    continue

                # Convert to NumPy array with proper shape
                points = np.array(points, dtype=np.int32)

                # Ensure correct shape for cv2.fillPoly
                points = points.reshape((-1, 1, 2))

                # Draw the polygon on the mask image
                cv2.fillPoly(mask, [points], 255)

            # Save the mask image
            mask_filename = os.path.splitext(xml_file)[0] + '_mask.jpg'
            mask_filepath = os.path.join(path_to_bi_maps, mask_filename)
            cv2.imwrite(mask_filepath, mask)
            print(f"Saved: {mask_filepath}")

# Example usage
convert_xml_to_mask('Zebra_fish_data/test_data_withxml/test', 'Zebra_fish_data/test_data_withxml/masks')
# Out:
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-01.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-01_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-03.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-03_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-04.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-04_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-05.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-05_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-06.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-06_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-07.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-07_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-08.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-08_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-09.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-09_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-10.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-10_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-11.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-11_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-12.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-12_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-13.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-13_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-14.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-14_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-15.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-15_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-16.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-16_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-17.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-17_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-18.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-18_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-19.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-19_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-20.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-20_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-21.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-21_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-22.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-22_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-23.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-23_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-24.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-24_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-25.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-25_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-26.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-26_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_20-27.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_20-27_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-01.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-01_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-02.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-02_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-03.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-03_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-04.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-04_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-06.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-06_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-07.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-07_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-08.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-08_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-09.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-09_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-10.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-10_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-11.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-11_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-12.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-12_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-13.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-13_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-14.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-14_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-15.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-15_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-16.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-16_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-17.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-17_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-18.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-18_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-19.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-19_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-20.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-20_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-21.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-21_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-22.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-22_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-23.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-23_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-24.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-24_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-25.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-25_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-26.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-26_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-27.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-27_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-28.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-28_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-29.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-29_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_21-30.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_21-30_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-01.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-01_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-02.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-02_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-03.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-03_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-04.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-04_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-05.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-05_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-06.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-06_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-07.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-07_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-08.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-08_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-09.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-09_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-10.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-10_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-11.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-11_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-12.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-12_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-13.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-13_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-14.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-14_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-15.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-15_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-16.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-16_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-17.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-17_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-18.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-18_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-19.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-19_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-20.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-20_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-21.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-21_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-22.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-22_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-23.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-23_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-24.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-24_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-25.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-25_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-26.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-26_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-27.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-27_mask.jpg
# Processing: Zebra_fish_data/test_data_withxml/test\PlatteA_119hpf_pr_22-28.xml
# Saved: Zebra_fish_data/test_data_withxml/masks\PlatteA_119hpf_pr_22-28_mask.jpg
